# %% [markdown]
# # Análisis Exploratorio de Datos (EDA)
#
# Este notebook realiza el análisis exploratorio del dataset de investigadores
# del Observatorio de Ciencia, Tecnología e Innovación de MinCiencias.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta = "../datos/raw/investigadores_consolidado.xlsx"

df = pd.read_excel(ruta)

df.head()

# %%
#información del dataset
df.info()

# %%
#estadísticas
df.describe()

# %%
df["NME_GENERO_PR"].value_counts().plot(kind="bar")

plt.title("Distribución de investigadores por género")
plt.show()
