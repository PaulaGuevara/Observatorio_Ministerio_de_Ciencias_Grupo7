# %%
import pandas as pd
# base
df = pd.read_excel('/content/Investigadores_Consolidado.xlsx')

# %%
df_2021 = df[df['ANO_CONVO'].astype(str).str.contains('2021')]
display(df_2021.head())
# Out:
#        ID_CONVOCATORIA          NME_CONVOCATORIA   ANO_CONVO  ID_PERSONA_PR  \
# 29797               21  Convocatoria 894 de 2021  25/02/2021         157791
# 29798               21  Convocatoria 894 de 2021  25/02/2021         350109
# 29799               21  Convocatoria 894 de 2021  25/02/2021          38164
# 29800               21  Convocatoria 894 de 2021  25/02/2021          19402
# 29801               21  Convocatoria 894 de 2021  25/02/2021          33189
#
#       ID_AREA_CON_PR           NME_ESP_AREA_PR             NME_AREA_PR  \
# 29797           6D07  Arquitectura y Urbanismo                    Arte
# 29798           6A01                  Historia  Historia y Arqueología
# 29799           5B01                  Economía     Economía y Negocios
# 29800           1D03            Química Física       Ciencias Químicas
# 29801           1C06                    Óptica        Ciencias Físicas
#
#          NME_GRAN_AREA_PR NME_GENERO_PR NME_PAIS_NAC_PR  ... EDAD_ANOS_PR  \
# 29797         Humanidades     Masculino        Colombia  ...        60.75
# 29798         Humanidades      Femenino        Exterior  ...        42.50
# 29799   Ciencias Sociales     Masculino        Colombia  ...        61.91
# 29800  Ciencias Naturales     Masculino        Colombia  ...        67.66
# 29801  Ciencias Naturales     Masculino        Colombia  ...        42.00
#
#       NME_PAIS_RES_PR NME_REGION_RES_PR  NME_DEPARTAMENTO_RES_PR  \
# 29797        Colombia      Eje Cafetero                Antioquia
# 29798        Exterior          Exterior                 Exterior
# 29799        Colombia          Pacífico          Valle del Cauca
# 29800        Colombia            Caribe                  Córdoba
# 29801        Colombia      Eje Cafetero                Antioquia
#
#       NME_MUNICIPIO_RES_PR COD_DANE_RES_PR  ID_VICTIMA_CONFLICTO  \
# 29797             Medellín          5001.0                    No
# 29798             Exterior             NaN           No registra
# 29799                 Cali         76001.0                    No
# 29800             Montería         23001.0                    No
# 29801             Medellín          5001.0                    No
#
#           TXT_GRUPO_ETNICO TXT_POBLACION_DISCA                INST_FILIA
# 29797  Ningún grupo étnico             Ninguna                       NaN
# 29798        No disponible       No disponible                       NaN
# 29799  Ningún grupo étnico             Ninguna     UNIVERSIDAD DEL VALLE
# 29800  Ningún grupo étnico             Ninguna    UNIVERSIDAD DE CORDOBA
# 29801  Ningún grupo étnico             Ninguna  UNIVERSIDAD DE ANTIOQUIA
#
# [5 rows x 30 columns]

# %%
print("Dimensiones 2021:")
print(df_2021.shape)

print(" Datos 2021:")
display(df_2021.describe())
# Out:
# Dimensiones 2021:
# (21094, 30)
#  Datos 2021:
#        ID_CONVOCATORIA  ID_PERSONA_PR  COD_DANE_NAC_PR  NRO_ORDEN_FORM_PR  \
# count          21094.0   2.109400e+04     20070.000000       21094.000000
# mean              21.0   8.371090e+05     29270.129696          16.470940
# std                0.0   5.705953e+05     26314.479449           1.005218
# min               21.0   2.000000e+01         5.000000           0.000000
# 25%               21.0   2.588450e+05     11001.000000          16.000000
# 50%               21.0   8.288935e+05     15001.000000          17.000000
# 75%               21.0   1.397125e+06     54001.000000          17.000000
# max               21.0   2.010112e+06     99001.000000          18.000000
#
#        ORDEN_CLAS_PR  EDAD_ANOS_PR  COD_DANE_RES_PR
# count   21094.000000  21093.000000     20343.000000
# mean       12.518157     44.634622     25854.856707
# std         0.749359     13.354573     25427.349779
# min        12.000000     17.580000         5.000000
# 25%        12.000000     36.910000     11001.000000
# 50%        12.000000     43.080000     11001.000000
# 75%        13.000000     51.250000     47001.000000
# max        15.000000    956.250000     97001.000000

# %%
# Faltantes
missing_values = df_2021.isnull().sum()

# Columnas con faltantes
print("Columns with missing values and their counts:")
print(missing_values[missing_values > 0])
# Out:
# Columns with missing values and their counts:
# COD_DANE_NAC_PR    1024
# EDAD_ANOS_PR          1
# COD_DANE_RES_PR     751
# INST_FILIA         2318
# dtype: int64

# %%
# Revision de duplicados
duplicate_rows = df_2021.duplicated().sum()
print("Filas duplicadas:", duplicate_rows)
# Out:
# Filas duplicadas: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count the occurrences of each gender
gender_counts = df_2021['NME_GENERO_PR'].value_counts()

# Create a bar plot
plt.figure(figsize=(8, 6))
sns.barplot(x=gender_counts.index, y=gender_counts.values)
plt.title('Distribución de Sexo de los Investigadores (2021)')
plt.xlabel('Sexo')
plt.ylabel('Cantidad de Investigadores')
plt.show()

# %%
# Count the occurrences of each education level
education_counts = df_2021['NME_NIV_FORM_PR'].value_counts()

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=education_counts.index, y=education_counts.values)
plt.title('Cantidad de Investigadores por Nivel de Formación (2021)')
plt.xlabel('Nivel de Formación')
plt.ylabel('Cantidad de Investigadores')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
# Count the occurrences of each region of residence
region_counts = df_2021['NME_REGION_RES_PR'].value_counts()

# Create a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=region_counts.index, y=region_counts.values)
plt.title('Cantidad de Investigadores por Región de Residencia (2021)')
plt.xlabel('Región de Residencia')
plt.ylabel('Cantidad de Investigadores')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
